# %% [markdown]
# <a href="https://colab.research.google.com/github/ErikuNyang/comp542-iris/blob/main/iris_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# load data using Pandas and return a Pandas DataFrame object
# iris.csv file is uploaded to my Github Repo (Url must have the raw view url)
import pandas as pd
url = 'https://raw.githubusercontent.com/ErikuNyang/comp542-iris/main/iris.csv'
def load_iris_data():
  return pd.read_csv(url, sep=',')

# %%
# Data Loading and testing
iris = load_iris_data()
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# a) How many tuples does the Iris data set have?
print(iris.index)
print("There are",len(iris),"rows in Iris data frame")
# Out:
# RangeIndex(start=0, stop=150, step=1)
# There are 150 rows in Iris data frame

# %%
# b) How many features does the Iris data set have? Print a name list
print(iris.columns)
print("There are",len(iris.columns),"features in Iris data frame")
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'], dtype='object')
# There are 5 features in Iris data frame

# %%
# c) What's the data type for each feature
print("Features        Data Type")
print("-------------------------")
print(iris.dtypes)
# Out:
# Features        Data Type
# -------------------------
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# class            object
# dtype: object

# %%
# d) How many of each species do you have?

# %%
# e) What’s the mean, median, and quantiles and ranges (max-min) 
# for each petal and sepal measurement?

#print("Mean\n", iris.mean(numeric_only=True))
#print("\nMedian\n",iris.median(numeric_only=True))
#print("\nQuantile\n",iris.quantile(numeric_only=True))
print(len(iris.max(numeric_only=True)), iris.max(numeric_only=True))
print(iris.min())
# Out:
# 4 sepal_length    7.9
# sepal_width     4.4
# petal_length    6.9
# petal_width     2.5
# dtype: float64
# sepal_length            4.3
# sepal_width             2.0
# petal_length            1.0
# petal_width             0.1
# class           Iris-setosa
# dtype: object

# %%
# f) Make a scatter plot of sepal_length vs sepal_width. 
# %matplotlib inline draws in the IPython shell that we are running and not in a separate output window.
# %matplotlib inline      
import matplotlib.pyplot as plt
iris.plot(kind="scatter", x="sepal_length", y="sepal_width", alpha=0.25)

# %%
# g) Create four individual histogram plots in a single figure, where each plot contains one feature 
# (petal_width, petal_length, sepal_width, sepal_length). Hint: use Pandas library.
# %matplotlib inline
iris.plot.hist(bins=50)

# %%
# h) Make a boxplot of each petal and sepal measurement.  
iris.plot(kind="box")

# %%
# i) Make a scatter plot matrix to examine the correlation between each of the measurements. 
from pandas.plotting import scatter_matrix
attributes = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']
scatter_matrix(iris[attributes], figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7faa1985d1f0>,
# ...
#       dtype=object)
